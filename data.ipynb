# %%
import pandas as pd 

pd.read_csv('assets/filtered_data.csv')
# Out:
#                      Name   Category                Film  Win_Oscar?  \
# 0     Richard Barthelmess      ACTOR           The Noose       False
# 1           Emil Jannings      ACTOR    The Last Command        True
# 2          Louise Dresser    ACTRESS     A Ship Comes In       False
# 3            Janet Gaynor    ACTRESS          7th Heaven        True
# 4          Gloria Swanson    ACTRESS      Sadie Thompson       False
# ...                   ...        ...                 ...         ...
# 2326           Sean Baker  DIRECTING               Anora        True
# 2327         Brady Corbet  DIRECTING       The Brutalist       False
# 2328        James Mangold  DIRECTING  A Complete Unknown       False
# 2329      Jacques Audiard  DIRECTING        Emilia Pérez       False
# 2330      Coralie Fargeat  DIRECTING       The Substance       False
#
#       Year_Ceremony  Gender Race or Ethnicity Sexual orientation Religion  Age
# ...

# %%
categories = ['Race or Ethnicity', 'Gender', 'Religion', 'Age', 'Sexual orientation']
df = pd.read_csv('assets/filtered_data.csv')

# filter columns 
df = df[categories]

# %%
# describe the data
for category in categories:
    print(f"Category: {category}")
    print(df[category].value_counts())
    print("\n")
# Out:
# Category: Race or Ethnicity
# Race or Ethnicity
# White                 2140
# Black                   97
# Hispanic                42
# Asian                   22
# Multiracial             16
# Middle Eastern           5
# Na                       4
# Asian/Indian             3
# American Aborigine       2
# Name: count, dtype: int64
#
#
# Category: Gender
# Gender
# Male      1395
# Female     936
# Name: count, dtype: int64
#
#
# Category: Religion
# Religion
# Na                       1534
# Roman Catholic            262
# Jewish                    215
# Atheist                    61
# Protestant                 26
# Born-Again Christian       23
# Agnostic                   23
# Presbyterian               21
# Baptist                    21
# Anglican/Episcopalian      20
# Lutheran                   19
# Christian Science          18
# Buddhist                   14
# Quaker                     12
# Mormon                     10
# Deist                      10
# ...
